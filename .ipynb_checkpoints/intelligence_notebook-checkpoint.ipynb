# %%
import pandas as pd
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Data processing

# %% [markdown]
# Load the csv file with the data using the pandas library.

# %%
df = pd.read_csv('wsnDB.csv')
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
#print(df.to_string())

# %% [markdown]
# Change the dtype of the "time" column to datetime64
# * tip: use the pd.to_datetime function()

# %% [markdown]
# Create a new dataframe with the "time" column and the column with sensor data of your interest

# %%
temperature_data = {
    "Timestamp": df['Timestamp'],
    "Temperature": df['Temperature']
} 

temperature_df = pd.DataFrame(temperature_data)
temperature_df['Timestamp'] = pd.to_datetime(temperature_df['Timestamp'])

humidity_data = {
    "Timestamp": df['Timestamp'],
    "Humidity": df['Humidity']
}

humidity_df = pd.DataFrame(humidity_data)

# %% [markdown]
# At this point it is advisasble to resample the dataframe (i.e. hourly) and create a new one, as the data is sampled per 20 seconds, and the statistical models will not be able to handle all the data at once.
# Tips:
# * set the index of the dataframe to be the "time" column
# * use .resample() of the pandas library function to resample the dataset and get the mean for each timestamp you create
# * store this new dataframe to an appropriately named one.

# %%
temperature_df.set_index('Timestamp', inplace=True)
#print(df.to_string()) 
temperature_df = temperature_df.resample('1Min').mean()
temperature_df_hourly = temperature_df['Temperature']

temperature_array = temperature_df.to_numpy()


##

# %% [markdown]
# Use the new dataframe you created to create an array with the values of the sensor and name it approprietly.

# %% [markdown]
# # Statistical Models

# %% [markdown]
# ## ARIMA model

# %%
# import the needed packages
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# %% [markdown]
# Set a new variable that will hold the column of the dataframe with the sensor data as a list and name it approprietly.

# %%
temperature = temperature_df

# %% [markdown]
# Split the dataset

# %%
train_size = int(len(temperature) * 0.8)
train, test = temperature[0:train_size], temperature[train_size:len(temperature)]

# %% [markdown]
# Load an ARIMA model and fit it to the data

# %%
model_train = ARIMA(train['Temperature'], order=(1, 0, 1))
model_train_fit = model_train.fit()

# %% [markdown]
# Make a forecast for as many steps as you want (prefferebly the same number of values as test set).

# %%
test_forecast = model_train_fit.forecast(steps=len(test))

# %% [markdown]
# Plot the results Actual vs Predicted values using matplotlib.

# %%
plt.figure(figsize=(14,7))
plt.plot(train, label='Training Data')
plt.plot(test['Temperature'], label='Actual Data', color='orange')
plt.plot(test_forecast, label='Forecasted Data', color='green')
plt.title('ARIMA Model Evaluation')
plt.xlabel('Date')
plt.ylabel('Number of Births')
plt.legend()
plt.show()

# %% [markdown]
# Calculate the below metrics for the model

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

mae = mean_absolute_error(test['Temperature'], test_forecast)
print("Mean absolute error:",mae)
mse = mean_squared_error(test['Temperature'], test_forecast)
print("Mean squaered error:",mse)
mape = mean_absolute_percentage_error(test['Temperature'], test_forecast)
print("Mean absolute percentage error:", mape)
# Out:
# Mean absolute error: 0.08075561900132026
# Mean squaered error: 0.013061889689010425
# Mean absolute percentage error: 0.003097999310415348

# %% [markdown]
# # SARIMAX model
# For the sarima model the same steps as the ARIMA model should be followed. Only the model call changes.

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

model_sar = SARIMAX(train['Temperature'], order=(1, 0, 1))

# %%
model_fit = model_sar.fit()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -5.50571D-01    |proj g|=  2.10489D-01
#
# At iterate    5    f= -5.56756D-01    |proj g|=  6.96177D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      9     15      1     0     0   1.229D-05  -5.568D-01
#   F = -0.55678044332087040
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.

# %%
forecast = model_fit.forecast(steps=len(test))

# %%
plt.plot(test)
plt.plot(forecast)
plt.legend(['Actual', 'Predicted'])
plt.show()

# %% [markdown]
# Calculate the below metrics for the model

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

mae = mean_absolute_error(test['Temperature'], test_forecast)
print("Mean absolute error:",mae)
mse = mean_squared_error(test['Temperature'], test_forecast)
print("Mean squaered error:",mse)
mape = mean_absolute_percentage_error(test['Temperature'], test_forecast)
print("Mean absolute percentage error:", mape)
# Out:
# Mean absolute error: 0.08075561900132026
# Mean squaered error: 0.013061889689010425
# Mean absolute percentage error: 0.003097999310415348

# %% [markdown]
# ### You can perform the analysis for whichever sensor you choose. You may do it for all of them or one. It is advised to tune the parameters to achieve a better results but it is not necessary. You can also use GridSearchCV form sklearn to automatically optimize the parameters.

# %% [markdown]
# # Neural Network Models

# %% [markdown]
# ## Data Processing and preparation

# %% [markdown]
# For the machine learning models the processing of the dataset changes a bit.

# %%
#As an example lets say we have the temperature array we created earlier.
temperature = temperature_df["Temperature"]

# We need to normalize the data
#Calculate the mean
mean = temperature.mean()
# Calculate the std
std = temperature.std()
# Use standard methodology to normalize the data (original_values - mean) /std
temperature = (temperature - mean) / std

# %% [markdown]
# Again, it is suggested you have already resampled the data as training with a large amount of instances coulf be really slow especially withoutt a dedicated GPU for acceleration. For a Machine Learning Neural Network Model we need to transform our data into information and target values. To do that we must create an array of features (past values) with a target (value after these 10 values for example).

# %%
# Create the LSTM input sequence
look_back = 5


X = []
y = []
for i in range(look_back, len(temperature)):
    X.append(temperature.iloc[i-look_back:i])
    y.append(temperature.iloc[i])

X = np.array(X)
y = np.array(y)

# Split the data into training and testing sets
train_size = int(len(X) * 0.7)
X_train, y_train = X[:train_size], y[:train_size]
X_test, y_test = X[train_size:], y[train_size:]

# Reshape the input data for the model
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# The above requires array comprehension but as it the not the focus of this project please just change the look back according to the dataset you created (resample, original dataset etc.)

# %% [markdown]
# #### LSTM

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
# Define the LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
history=model.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.1927
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1467
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8660
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6844
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4973
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4400
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3842
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4019
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4147
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5483
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4750
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5077
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4406
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4743
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3969
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4432
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3894
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3990
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4382
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4257
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4000
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4898
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4747
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3915
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4070
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4729
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4359
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3447
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4651
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4648
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3780
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4102
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4019
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4438
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4087
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4532
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4169
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3619
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3692
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3680
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3885
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4243
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3683
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3748
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3971
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3765
# Epoch 47/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3996
# Epoch 48/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3811
# Epoch 49/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3988
# Epoch 50/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3562
# Epoch 51/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3464
# Epoch 52/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3566
# Epoch 53/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4158
# Epoch 54/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3553
# Epoch 55/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3698
# Epoch 56/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3431
# Epoch 57/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3626
# Epoch 58/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3972
# Epoch 59/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3212
# Epoch 60/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3406
# Epoch 61/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3298
# Epoch 62/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2969
# Epoch 63/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3704
# Epoch 64/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3725
# Epoch 65/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3055
# Epoch 66/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3531
# Epoch 67/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3349
# Epoch 68/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3055
# Epoch 69/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3229
# Epoch 70/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2984
# Epoch 71/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3213
# Epoch 72/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3247
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3301
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3561
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3589
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3422
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3233
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3037
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3481
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3518
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2983
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3538
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3095
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3579
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3605
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3777
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3096
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3991
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3259
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3872
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3556
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3762
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3595
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3418
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3177
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3500
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3691
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3349
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3277
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2707

# %% [markdown]
# Plot the training accuracy over the course of the training and loss from the model.history paramater

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 2
#       1 plt.plot(history.history['loss'])
# ----> 2 plt.plot(history.history['val_loss'])
#       3 plt.title('Model loss')
#       4 plt.ylabel('Loss')
#
# KeyError: 'val_loss'

# %%
# Predict future values
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Create an empty array for plotting
predict_plot = np.empty_like(temperature)
predict_plot[:] = np.nan

# Align predictions
predict_plot[look_back:train_size+look_back] = train_predict.flatten()
predict_plot[train_size+look_back:] = test_predict.flatten()

# Plot baseline and predictions
plt.figure(figsize=(12, 6))
plt.plot(temperature.values, label='Actual')
plt.plot(predict_plot, label='Predicted')
plt.title('Temperature Prediction')
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.legend()
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
train_predict_plot = np.empty_like(temperature)
train_predict_plot[:] = np.nan
train_predict_plot[look_back:train_size+look_back] = train_predict.flatten()

test_predict_plot = np.empty_like(temperature)
test_predict_plot[:] = np.nan
test_predict_plot[train_size+look_back:] = test_predict.flatten()

# Plot the actual values and the predictions
plt.figure(figsize=(12, 6))
plt.plot(temperature.values, label='Actual')
plt.plot(train_predict_plot, label='Train Predict')
plt.plot(test_predict_plot, label='Test Predict')
plt.title('Temperature Prediction')
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.legend()
plt.show()

# %% [markdown]
# Calculate the mean_absolute_error, mean_squared_error and mean_absolute_percentage_error and the accuracy of the model.

# %%
mae = mean_absolute_error(y_test, test_predict)
mse = mean_squared_error(y_test, test_predict)
mape = mean_absolute_percentage_error(y_test, test_predict)

# %% [markdown]
# #### RNN Model

# %% [markdown]
# Bonus: Only the model changes between these two examples. Create your own SimpleRNN model using the LSTM model as a guidline and calculate the same training metrics as before as well as visualize the same results.

# %%
from keras.layers import  SimpleRNN

# %% [markdown]
# # Final guidelines
# * You can use this notebook or create multiple notebooks as you fit (i.e. for each sensor, for each model).
# * Do not hesitate to play around with hyper parapeters optimization. While the end goal is not to achieve the best results the effort will be valued.
# * Try to mess around with the data. Do the analysis for more than one sensor and try different sampling rates. We would like to see more than one datasets as a basis for your results.
